# %% [markdown]
# # Datawrapper - making the charts with USGS data
#
# - chart of population exposed by shake intensity
# - chart of aftershocks

# %%
import pandas as pd
from datawrapper import Datawrapper
import os
import geopandas as gpd

# %%
# Récupère ta clé API depuis les variables d'environnement
api_key = os.getenv("DATAWRAPPER_API_KEY")  # remplace par le nom exact de ta variable

# Initialise Datawrapper
dw = Datawrapper(api_key)



# Tu peux maintenant utiliser dw.account_info()
info = dw.account_info()
print(info)
# Out:
# This method is deprecated and will be removed in a future version. Use get_account_info instead.
# {'id': 489654, 'email': 'olaf.koenig@tamedia.ch', 'name': 'Olaf König', 'role': 'editor', 'language': 'en-US', 'presenceColor': 'color-dw-presence-30', 'avatar': None, 'customAvatar': None, 'teams': [{'id': 'tagesanzeiger', 'name': 'Tamedia', 'url': '/v3/teams/tagesanzeiger', 'active': False}], 'chartCount': 672, 'url': '/v3/users/489654', 'activeTeam': None, 'entitlements': {}}

# %% [markdown]
# ## Import data

# %%
output_dir = "data_input/USGS"

# %%
### Data population exposure

# %%
df_exposure = pd.read_csv(f"{output_dir}/exposure_population_by_country_mmi.csv")
label_exposure = pd.read_csv(f"{output_dir}/mmi_intensity_category.csv")
print(df_exposure.head())
print(label_exposure.head())

df_exposure = pd.merge(
    df_exposure,
    label_exposure,
    how="left",
    left_on="mmi",
    right_on="Intensity"
)

df_exposure
# Out:
#   country  mmi  pop_exposure country_name_en country_name_fr country_name_de
# 0     ALL    1             0           Total           Total           Total
# 1     ALL    2             0           Total           Total           Total
# 2     ALL    3      32989235           Total           Total           Total
# 3     ALL    4     163708636           Total           Total           Total
# 4     ALL    5      24656409           Total           Total           Total
#    Intensity Shaking_EN   Damage_EN     Shaking_DE    Damage_DE    Shaking_FR  \
# 0          1   Not felt         NaN  Nicht fühlbar        Keine  Non ressenti
# 1          2       Weak         NaN        Schwach        Keine        Faible
# 2          3       Weak         NaN        Schwach        Keine        Faible
# 3          4      Light         NaN         Leicht        Keine         Léger
# 4          5   Moderate  Very light         Mässig  Sehr gering        Modéré
#
#     Damage_FR
# 0       Aucun
# 1       Aucun
# 2       Aucun
# 3       Aucun
# 4  Très léger
#    country  mmi  pop_exposure country_name_en country_name_fr country_name_de  \
# 0      ALL    1             0           Total           Total           Total
# 1      ALL    2             0           Total           Total           Total
# 2      ALL    3      32989235           Total           Total           Total
# 3      ALL    4     163708636           Total           Total           Total
# 4      ALL    5      24656409           Total           Total           Total
# ..     ...  ...           ...             ...             ...             ...
# 95      TH    6        141478        Thailand       Thaïlande        Thailand
# 96      TH    7             0        Thailand       Thaïlande        Thailand
# 97      TH    8             0        Thailand       Thaïlande        Thailand
# 98      TH    9             0        Thailand       Thaïlande        Thailand
# 99      TH   10             0        Thailand       Thaïlande        Thailand
#
#     Intensity   Shaking_EN       Damage_EN     Shaking_DE    Damage_DE  \
# 0           1     Not felt             NaN  Nicht fühlbar        Keine
# 1           2         Weak             NaN        Schwach        Keine
# 2           3         Weak             NaN        Schwach        Keine
# 3           4        Light             NaN         Leicht        Keine
# 4           5     Moderate      Very light         Mässig  Sehr gering
# ..        ...          ...             ...            ...          ...
# 95          6       Strong           Light          Stark       Gering
# 96          7  Very strong        Moderate     Sehr stark       Mittel
# 97          8       Severe  Moderate/heavy         Heftig  Mittel/hoch
# 98          9      Violent           Heavy         Heftig         Hoch
# 99         10      Extreme      Very heavy         Extrem    Sehr hoch
#
#       Shaking_FR         Damage_FR
# 0   Non ressenti             Aucun
# 1         Faible             Aucun
# 2         Faible             Aucun
# 3          Léger             Aucun
# 4         Modéré        Très léger
# ..           ...               ...
# 95          Fort             Léger
# 96     Très fort            Modéré
# 97        Sévère  Modéré/important
# 98       Violent         Important
# 99       Extrême    Très important
#
# [100 rows x 13 columns]

# %% [markdown]
# ### Cleaning exposure and transform to wide

# %%
df_wide = (
    df_exposure[df_exposure["country"].isin(["ALL", "MM"])]
    [["mmi", "Shaking_EN", "country_name_en", "pop_exposure"]]
    .pivot(index=["mmi", "Shaking_EN"], columns="country_name_en", values="pop_exposure")
    .reset_index()
)
df_wide = df_wide[~df_wide['mmi'].isin([1, 2])]

df_wide["pct_myanmar"] = (
    df_wide["Myanmar (Burma)"] / df_wide["Total"] * 100
).clip(upper=100).round(1)

# %% [markdown]
# ### Create dw exposure chart

# %%
folder_id = "332403"

# %%
# # The function create_chart() can take four arguments: title, chart_type, data, and folder_id.


# dw_exposure = dw.create_chart(
#     title="Population exposure at the earthquake",
#     chart_type="tables",
#     data = df_wide,
#     folder_id=folder_id
# )

# %%
# dw_exposure_id = dw_exposure['id']
# print(dw_exposure_id)

dw_exposure_id = "dQpEY"
# Out:
# dQpEY

# %% [markdown]
# #### Update data

# %%
dw.add_data(dw_exposure_id, df_wide)
# Out:
# True

# %% [markdown]
# #### Publish chart

# %%
dw.publish_chart(dw_exposure_id)

dw_exposure_iframe = dw.get_iframe_code(dw_exposure_id)

# %%
# Out:
# '<iframe title="The Earthquake’s Impact Fell Heaviest on Myanmar’s Population" aria-label="Table" id="datawrapper-chart-dQpEY" src="https://datawrapper.dwcdn.net/dQpEY/4/" scrolling="no" frameborder="0" style="border: none;" width="320" height="446" data-external="1"></iframe>'

# %% [markdown]
# ### Aftershocks data

# %%
dw_aftershocks = gpd.read_file(f"{output_dir}/aftershock_with_distance.gpkg")
dw_aftershocks
# Out:
#             id                             time  magnitude  depth  latitude  \
# 0   us7000pn9s 2025-03-28 06:20:52.715000+00:00        7.7   10.0   22.0110
# 1   us7000pn9z 2025-03-28 06:32:04.777000+00:00        6.7   10.0   21.6975
# 2   us7000pncy 2025-03-28 06:39:14.645000+00:00        4.8   10.0   19.8979
# 3   us7000pncv 2025-03-28 06:42:24.760000+00:00        4.9   10.0   21.8377
# 4   us7000pnb6 2025-03-28 06:45:44.906000+00:00        4.9   10.0   19.1284
# ..         ...                              ...        ...    ...       ...
# 69  us6000q72i 2025-04-18 18:01:22.215000+00:00        4.1   10.0   20.4354
# 70  us6000q7gc 2025-04-21 00:03:23.936000+00:00        4.2   10.0   29.1753
# 71  us6000q7ge 2025-04-21 01:07:50.979000+00:00        4.7   10.0   32.5723
# 72  us7000puj0 2025-04-23 16:09:01.885000+00:00        4.9   10.0   26.4164
# 73  us7000pv6f 2025-04-26 04:21:49.088000+00:00        5.1   10.0   31.0900
#
#     longitude magtype   gap   rms horizontal_error vertical_error  \
# 0     95.9363    None  None  None             None           None
# 1     95.9690    None  None  None             None           None
# 2     95.8026    None  None  None             None           None
# 3     95.8747    None  None  None             None           None
# 4     96.2075    None  None  None             None           None
# ..        ...     ...   ...   ...              ...            ...
# 69    96.1272    None  None  None             None           None
# 70    86.9720    None  None  None             None           None
# 71    93.3067    None  None  None             None           None
# 72   100.0261    None  None  None             None           None
# 73    98.9820    None  None  None             None           None
#
#     distance_to_fault_m  distance_to_fault_km                  geometry
# 0          4.841912e+03              4.841912    POINT (95.9363 22.011)
# 1          2.036882e+03              2.036882    POINT (95.969 21.6975)
# 2          3.629403e+04             36.294033   POINT (95.8026 19.8979)
# 3          1.157123e+04             11.571228   POINT (95.8747 21.8377)
# 4          6.474854e+03              6.474854   POINT (96.2075 19.1284)
# ..                  ...                   ...                       ...
# 69         4.795000e+03              4.795000   POINT (96.1272 20.4354)
# 70         1.168997e+06           1168.996823    POINT (86.972 29.1753)
# 71         1.149769e+06           1149.768632   POINT (93.3067 32.5723)
# 72         6.011740e+05            601.174035  POINT (100.0261 26.4164)
# 73         1.002432e+06           1002.431770      POINT (98.982 31.09)
#
# [74 rows x 14 columns]

# %% [markdown]
# ### Filter distance to fault

# %%
# Filtering distance
distance_to_fault = 100



dw_aftershocks_filtered = dw_aftershocks[dw_aftershocks["distance_to_fault_km"] <= distance_to_fault]

# %% [markdown]
# ### Clean time and accentuate sizes differences

# %%
df_aftershocks_filtered = dw_aftershocks_filtered.drop(columns="geometry").copy()

# Conversion en datetime, si nécessaire
df_aftershocks_filtered["time"] = pd.to_datetime(df_aftershocks_filtered["time"])

# Chronologie fine pour DW
df_aftershocks_filtered["datetime"] = df_aftershocks_filtered["time"].dt.strftime('%Y-%m-%d %H:%M')
df_aftershocks_filtered["iso8601"] = df_aftershocks_filtered["time"].dt.strftime("%Y-%m-%dT%H:%M:%SZ")

# Ajout du radius avec une fonction quadratique
def mag_to_radius(mag, base=2):
    return base + (mag - 3.5)**2.5

df_aftershocks_filtered["radius"] = df_aftershocks_filtered["magnitude"].apply(mag_to_radius)

# Sélection des colonnes clés
cols = ["id", "magnitude", "radius", "distance_to_fault_km", "datetime", "iso8601"]
df_aftershock_for_dw = df_aftershocks_filtered[cols].copy()

# %% [markdown]
# ### Create chart for aftershocks

# %%
# dw_aftershock = dw.create_chart(
#     title="Aftershocks",
#     chart_type="tables",
#     data = df_aftershock_for_dw,
# 10    95.8380    None  None  None             None           None
# 11    96.1170    None  None  None             None           None
# 12    95.3761    None  None  None             None           None
# 13    96.5422    None  None  None             None           None
# 14    96.2070    None  None  None             None           None
# 15    95.7390    None  None  None             None           None
# 16    95.9466    None  None  None             None           None
# 17    95.9659    None  None  None             None           None
# 18    96.0242    None  None  None             None           None
# 19    95.9561    None  None  None             None           None
# 20    95.8877    None  None  None             None           None
# 21    95.8997    None  None  None             None           None
# 22    96.0494    None  None  None             None           None
# 23    95.9969    None  None  None             None           None
# 25    96.0761    None  None  None             None           None
# 27    95.9811    None  None  None             None           None
# 28    95.9940    None  None  None             None           None
# 29    95.9429    None  None  None             None           None
# 30    95.9368    None  None  None             None           None
# 31    96.0305    None  None  None             None           None
# 32    95.8682    None  None  None             None           None
# 34    95.9969    None  None  None             None           None
# 35    95.6560    None  None  None             None           None
# 36    96.0154    None  None  None             None           None
# 37    95.9910    None  None  None             None           None
# 38    95.9636    None  None  None             None           None
# 39    96.0923    None  None  None             None           None
# 41    95.8772    None  None  None             None           None
# 42    96.0561    None  None  None             None           None
# 44    96.0733    None  None  None             None           None
# 46    96.0529    None  None  None             None           None
# 48    96.1609    None  None  None             None           None
# 49    95.9630    None  None  None             None           None
# 50    95.8838    None  None  None             None           None
# 51    95.9352    None  None  None             None           None
# 52    96.0058    None  None  None             None           None
# 54    95.9475    None  None  None             None           None
# 55    96.2808    None  None  None             None           None
# 56    96.0381    None  None  None             None           None
# 57    96.0731    None  None  None             None           None
# 60    96.0895    None  None  None             None           None
# 61    96.0897    None  None  None             None           None
# 63    95.5327    None  None  None             None           None
# 65    96.0243    None  None  None             None           None
# 67    96.1069    None  None  None             None           None
# 68    96.1235    None  None  None             None           None
# 69    96.1272    None  None  None             None           None
#
#     distance_to_fault_m  distance_to_fault_km                 geometry
# 0           4841.911795              4.841912   POINT (95.9363 22.011)
# 1           2036.881791              2.036882   POINT (95.969 21.6975)
# 2          36294.032829             36.294033  POINT (95.8026 19.8979)
# 3          11571.227728             11.571228  POINT (95.8747 21.8377)
# 4           6474.853617              6.474854  POINT (96.2075 19.1284)
# 5           9169.993542              9.169994  POINT (96.0667 22.0976)
# 6          11719.597959             11.719598  POINT (95.8669 22.0534)
# 7          31285.612831             31.285613  POINT (95.8927 22.7436)
# 8          30302.311849             30.302312  POINT (95.7353 22.6287)
# 9          35080.863305             35.080863  POINT (95.8531 22.7673)
# 10         14278.922146             14.278922   POINT (95.838 22.4361)
# 11         14610.699173             14.610699   POINT (96.117 22.2037)
# 12        129574.501956            129.574502   POINT (95.3761 23.501)
# 13         52477.634560             52.477635   POINT (96.5422 20.903)
# 14          2525.605994              2.525606   POINT (96.207 19.3628)
# 15         25184.957834             25.184958   POINT (95.739 22.5255)
# 16          3588.596241              3.588596  POINT (95.9466 22.0401)
# 17          1871.162183              1.871162  POINT (95.9659 21.9984)
# 18          7618.468933              7.618469  POINT (96.0242 20.2803)
# 19          3269.730417              3.269730   POINT (95.9561 21.784)
# 20         10384.603349             10.384603  POINT (95.8877 21.7546)
# 21          8724.569006              8.724569  POINT (95.8997 21.9947)
# 22          7523.147086              7.523147  POINT (96.0494 22.3954)
# 23          3713.389424              3.713389   POINT (95.9969 20.973)
# 25         10572.218051             10.572218  POINT (96.0761 19.6858)
# 27           692.167641              0.692168  POINT (95.9811 22.4771)
# 28         18155.837850             18.155838   POINT (95.994 19.7498)
# 29          4140.126693              4.140127  POINT (95.9429 22.0142)
# 30          3994.060540              3.994061  POINT (95.9368 22.2219)
# 31          9946.127278              9.946127  POINT (96.0305 22.5469)
# 32         14401.290944             14.401291  POINT (95.8682 22.5542)
# 34          1649.799621              1.649800  POINT (95.9969 22.0479)
# 35         32988.985512             32.988986    POINT (95.656 22.313)
# 36          3477.657746              3.477658  POINT (96.0154 22.0356)
# 37           654.221569              0.654222   POINT (95.991 21.9886)
# 38          1682.896687              1.682897  POINT (95.9636 22.0634)
# 39          3807.549525              3.807550  POINT (96.0923 20.0604)
# 41        123072.875961            123.072876   POINT (95.8772 23.579)
# 42          1992.607773              1.992608  POINT (96.0561 20.9095)
# 44          9257.099663              9.257100  POINT (96.0733 21.9162)
# 46          6507.861251              6.507861  POINT (96.0529 21.5705)
# 48         14063.177686             14.063178  POINT (96.1609 21.0805)
# 49         17998.093281             17.998093   POINT (95.963 22.6342)
# 50         35842.684766             35.842685   POINT (95.8838 22.784)
# 51          6773.844927              6.773845  POINT (95.9352 21.4447)
# 52          2245.205114              2.245205  POINT (96.0058 21.9457)
# 54          4237.100215              4.237100  POINT (95.9475 21.7193)
# 55           967.056322              0.967056   POINT (96.2808 19.004)
# 56           462.511416              0.462511  POINT (96.0381 20.9582)
# 57          4470.696845              4.470697  POINT (96.0731 21.0117)
# 60          5285.052094              5.285052  POINT (96.0895 19.9801)
# 61          7702.981676              7.702982  POINT (96.0897 21.2292)
# 63         65120.224411             65.120224    POINT (95.5327 19.82)
# 65          1040.269121              1.040269  POINT (96.0243 20.9483)
# 67         12950.943493             12.950943  POINT (96.1069 22.0411)
# 68         25606.592686             25.606593  POINT (96.1235 22.6589)
# 69          4795.000406              4.795000  POINT (96.1272 20.4354)

# %%
# S'assurer que le DataFrame est trié par 'time' croissante
df_aftershocks_filtered = df_aftershocks_filtered.sort_values("time")

# Prendre la date du tout premier aftershock comme point de départ
first_time = df_aftershocks_filtered["time"].iloc[0]

# Définir la fenêtre de 6 jours après ce timestamp
window_end = first_time + pd.Timedelta(days=6)

# Filtrer les aftershocks dans cette fenêtre
after_6days = df_aftershocks_filtered[
    (df_aftershocks_filtered["time"] >= first_time) &
    (df_aftershocks_filtered["time"] < window_end)
]

count = len(after_6days)
print(f"Nombre de tremblements de terre dans les 6 jours à partir du premier : {count}")
# Out:
# Nombre de tremblements de terre dans les 6 jours à partir du premier : 38
